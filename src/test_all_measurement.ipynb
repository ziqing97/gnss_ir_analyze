# %%
import os
import random


import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from pymap3d import enu2geodetic
import gmplot

import data_filter as dafi
import estimate_height as esth

apikey="AIzaSyBe1VW572pITHH7OBLt1Ziy1e9y0dl4kWw"

color_dict = esth.get_satellite_color()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [1], line 16
#      12 import estimate_height as esth
#      14 apikey="AIzaSyBe1VW572pITHH7OBLt1Ziy1e9y0dl4kWw"
# ---> 16 color_dict = esth.get_satellite_color()
#
# AttributeError: module 'estimate_height' has no attribute 'get_satellite_color'

# %%
meas_file = os.path.abspath("../data/documentation.xlsx")
df_meas = pd.read_excel(meas_file)

# %%
main_path = os.path.abspath('../data/20220522/2/')
data_dict = dafi.generate_dataframe(main_path)
satellite_list = data_dict.keys()
azimut_mask = [270,320]
elevation_mask = [0,60]
min_height = 2
max_height = 20 # meter
time_length = 25 # minutes
time_dict,height_dict,azimut_dict,elevation_dict,frequency_dict,power_dict = esth.estimate_all_satellite(main_path,azimut_mask,elevation_mask,min_height,max_height,time_length)
for satellite_code in time_dict:
    plt.scatter(elevation_dict[satellite_code],height_dict[satellite_code],label=satellite_code,color=color_dict[satellite_code])

plt.legend(loc="best")

# %%
main_path = os.path.abspath('../data/20220522/3/')
data_dict = dafi.generate_dataframe(main_path)
satellite_list = data_dict.keys()
azimut_mask = [230,260]
elevation_mask = [0,60]
min_height = 2
max_height = 20 # meter
time_length = 25 # minutes
time_dict,height_dict,azimut_dict,elevation_dict,frequency_dict,power_dict = esth.estimate_all_satellite(main_path,azimut_mask,elevation_mask,min_height,max_height,time_length)
for satellite_code in time_dict:
    plt.scatter(elevation_dict[satellite_code],height_dict[satellite_code],label=satellite_code,color=color_dict[satellite_code])

plt.legend(loc="best")

# %%
main_path = os.path.abspath('../data/20220526/2/')
data_dict = dafi.generate_dataframe(main_path)
satellite_list = data_dict.keys()
azimut_mask = [165,195]
elevation_mask = [0,60]
min_height = 2
max_height = 20 # meter
time_length = 25 # minutes
time_dict,height_dict,azimut_dict,elevation_dict,frequency_dict,power_dict = esth.estimate_all_satellite(main_path,azimut_mask,elevation_mask,min_height,max_height,time_length)
for satellite_code in time_dict:
    plt.scatter(elevation_dict[satellite_code],height_dict[satellite_code],label=satellite_code,color=color_dict[satellite_code])

plt.legend(loc="best")

# %%
main_path = os.path.abspath('../data/20220522/3/')
data_dict = dafi.generate_dataframe(main_path)
satellite_list = data_dict.keys()
azimut_mask = [100,160]
elevation_mask = [0,60]
min_height = 8
max_height = 14 # meter
time_length = 25 # minutes
time_dict,height_dict,azimut_dict,elevation_dict,frequency_dict,power_dict = esth.estimate_all_satellite(main_path,azimut_mask,elevation_mask,min_height,max_height,time_length)
for satellite_code in time_dict:
    plt.scatter(elevation_dict[satellite_code],height_dict[satellite_code],label=satellite_code,color=color_dict[satellite_code])

plt.legend(loc="best")

# %%
main_path = os.path.abspath('../data/20220811/2/')
date_str = "2022-08-11"

data_dict = dafi.generate_dataframe(main_path)
satellite_list = data_dict.keys()
azimut_mask = [270,330]
elevation_mask = [0,60]
min_height = 2
max_height = 20 # meter
time_length = 25 # minutes
time_dict,height_dict,azimut_dict,elevation_dict,frequency_dict,power_dict = esth.estimate_all_satellite(main_path,azimut_mask,elevation_mask,min_height,max_height,time_length)
for satellite_code in time_dict:
    plt.scatter(elevation_dict[satellite_code],height_dict[satellite_code],label=satellite_code,color=color_dict[satellite_code])

plt.legend(loc="best")

# %%
esth.plot_fresnel_zone(time_str="2022-08-11",equipment_index=2,azimut_dict=azimut_dict,elevation_dict=elevation_dict,height_dict=height_dict)

# %%
main_path = os.path.abspath('../data/20220811/3/')
data_dict = dafi.generate_dataframe(main_path)
satellite_list = data_dict.keys()
azimut_mask = [270,330]
elevation_mask = [0,60]
min_height = 2
max_height = 20 # meter
time_length = 25 # minutes
time_dict,height_dict,azimut_dict,elevation_dict,frequency_dict,power_dict = esth.estimate_all_satellite(main_path,azimut_mask,elevation_mask,min_height,max_height,time_length)
for satellite_code in time_dict:
    plt.scatter(elevation_dict[satellite_code],height_dict[satellite_code],label=satellite_code,color=color_dict[satellite_code])

plt.legend(loc="best")

# %%
esth.plot_fresnel_zone(time_str="2022-08-11",equipment_index=3,azimut_dict=azimut_dict,elevation_dict=elevation_dict,height_dict=height_dict)

# %%
main_path = os.path.abspath('../data/20220907/2/')
data_dict = dafi.generate_dataframe(main_path)
satellite_list = data_dict.keys()
azimut_mask = [270,330]
elevation_mask = [0,60]
min_height = 2
max_height = 20 # meter
time_length = 25 # minutes
time_dict,height_dict,azimut_dict,elevation_dict,frequency_dict,power_dict = esth.estimate_all_satellite(main_path,azimut_mask,elevation_mask,min_height,max_height,time_length)
for satellite_code in time_dict:
    plt.scatter(elevation_dict[satellite_code],height_dict[satellite_code],label=satellite_code,color=color_dict[satellite_code])

plt.legend(loc="best")

# %%
esth.plot_fresnel_zone(time_str="2022-09-07",equipment_index=2,azimut_dict=azimut_dict,elevation_dict=elevation_dict,height_dict=height_dict)

# %%
main_path = os.path.abspath('../data/20220907/3/')
data_dict = dafi.generate_dataframe(main_path)
satellite_list = data_dict.keys()
azimut_mask = [270,330]
elevation_mask = [0,60]
min_height = 2
max_height = 20 # meter
time_length = 25 # minutes
time_dict,height_dict,azimut_dict,elevation_dict,frequency_dict,power_dict = esth.estimate_all_satellite(main_path,azimut_mask,elevation_mask,min_height,max_height,time_length)
for satellite_code in time_dict:
    plt.scatter(elevation_dict[satellite_code],height_dict[satellite_code],label=satellite_code,color=color_dict[satellite_code])

plt.legend(loc="best")

# %%
esth.plot_fresnel_zone(time_str="2022-09-07",equipment_index=3,azimut_dict=azimut_dict,elevation_dict=elevation_dict,height_dict=height_dict)

# %%
main_path = os.path.abspath('../data/20221004/2/')
data_dict = dafi.generate_dataframe(main_path)
satellite_list = data_dict.keys()
azimut_mask = [270,330]
elevation_mask = [0,60]
min_height = 2
max_height = 20 # meter
time_length = 25 # minutes
time_dict,height_dict,azimut_dict,elevation_dict,frequency_dict,power_dict = esth.estimate_all_satellite(main_path,azimut_mask,elevation_mask,min_height,max_height,time_length)
for satellite_code in time_dict:
    plt.scatter(elevation_dict[satellite_code],height_dict[satellite_code],label=satellite_code,color=color_dict[satellite_code])

plt.legend(loc="best")

# %%
esth.plot_fresnel_zone(time_str="2022-10-04",equipment_index=2,azimut_dict=azimut_dict,elevation_dict=elevation_dict,height_dict=height_dict)

# %%
main_path = os.path.abspath('../data/20221004/3/')
data_dict = dafi.generate_dataframe(main_path)
satellite_list = data_dict.keys()
azimut_mask = [270,330]
elevation_mask = [0,60]
min_height = 2
max_height = 20 # meter
time_length = 25 # minutes
time_dict,height_dict,azimut_dict,elevation_dict,frequency_dict,power_dict = esth.estimate_all_satellite(main_path,azimut_mask,elevation_mask,min_height,max_height,time_length)
for satellite_code in time_dict:
    plt.scatter(elevation_dict[satellite_code],height_dict[satellite_code],label=satellite_code,color=color_dict[satellite_code])

plt.legend(loc="best")

# %%
esth.plot_fresnel_zone(time_str="2022-10-04",equipment_index=3,azimut_dict=azimut_dict,elevation_dict=elevation_dict,height_dict=height_dict)

# %%
main_path = os.path.abspath('../data/20221031/2/')
data_dict = dafi.generate_dataframe(main_path)
satellite_list = data_dict.keys()
azimut_mask = [270,330]
elevation_mask = [0,60]
min_height = 2
max_height = 20 # meter
time_length = 25 # minutes
time_dict,height_dict,azimut_dict,elevation_dict,frequency_dict,power_dict = esth.estimate_all_satellite(main_path,azimut_mask,elevation_mask,min_height,max_height,time_length)
for satellite_code in time_dict:
    plt.scatter(elevation_dict[satellite_code],height_dict[satellite_code],label=satellite_code,color=color_dict[satellite_code])

plt.legend(loc="best")

# %%
esth.plot_fresnel_zone(time_str="2022-10-31",equipment_index=2,azimut_dict=azimut_dict,elevation_dict=elevation_dict,height_dict=height_dict)

# %%
main_path = os.path.abspath('../data/20221031/3/')
data_dict = dafi.generate_dataframe(main_path)
satellite_list = data_dict.keys()
azimut_mask = [270,330]
elevation_mask = [0,60]
min_height = 2
max_height = 4 # meter
time_length = 25 # minutes
time_dict,height_dict,azimut_dict,elevation_dict,frequency_dict,power_dict = esth.estimate_all_satellite(main_path,azimut_mask,elevation_mask,min_height,max_height,time_length)
for satellite_code in time_dict:
    plt.scatter(elevation_dict[satellite_code],height_dict[satellite_code],label=satellite_code,color=color_dict[satellite_code])

plt.legend(loc="best")

# %%
esth.plot_fresnel_zone(time_str="2022-10-31",equipment_index=3,azimut_dict=azimut_dict,elevation_dict=elevation_dict,height_dict=height_dict)

# %%
main_path = os.path.abspath('../data/20221104/2/')
data_dict = dafi.generate_dataframe(main_path)
satellite_list = data_dict.keys()
azimut_mask = [300,330]
elevation_mask = [0,60]
min_height = 8
max_height = 16 # meter
time_length = 25 # minutes
time_dict,height_dict,azimut_dict,elevation_dict,frequency_dict,power_dict = esth.estimate_all_satellite(main_path,azimut_mask,elevation_mask,min_height,max_height,time_length)
for satellite_code in time_dict:
    plt.scatter(elevation_dict[satellite_code],height_dict[satellite_code],label=satellite_code,color=color_dict[satellite_code])

plt.legend(loc="best")

# %%
esth.plot_fresnel_zone(time_str="2022-11-04",equipment_index=2,azimut_dict=azimut_dict,elevation_dict=elevation_dict,height_dict=height_dict)

# %%
main_path = os.path.abspath('../data/20221104/3/')
data_dict = dafi.generate_dataframe(main_path)
satellite_list = data_dict.keys()
azimut_mask = [155,180]
elevation_mask = [0,60]
min_height = 8
max_height = 16 # meter
time_length = 25 # minutes
time_dict,height_dict,azimut_dict,elevation_dict,frequency_dict,power_dict = esth.estimate_all_satellite(main_path,azimut_mask,elevation_mask,min_height,max_height,time_length)
for satellite_code in time_dict:
    plt.scatter(elevation_dict[satellite_code],height_dict[satellite_code],label=satellite_code,color=color_dict[satellite_code])

plt.legend(loc="best")

# %%
for satellite_code in time_dict:
    plt.scatter(azimut_dict[satellite_code],height_dict[satellite_code],label=satellite_code,color=color_dict[satellite_code])

plt.legend(loc="best")

# %%
esth.plot_fresnel_zone(time_str="2022-11-04",equipment_index=3,azimut_dict=azimut_dict,elevation_dict=elevation_dict,height_dict=height_dict)
