# %%
import os

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

import data_filter as dafi
import estimate_height as esth
import lib_plot

apikey="AIzaSyBe1VW572pITHH7OBLt1Ziy1e9y0dl4kWw"

color_dict = lib_plot.get_satellite_color()

# %%
meas_file = os.path.abspath("../data/documentation.xlsx")
df_meas = pd.read_excel(meas_file)

# %%
main_path = os.path.abspath('../data/20220811/2/')
date_str = "2022-08-11"

data_dict = dafi.generate_dataframe(main_path)
satellite_list = data_dict.keys()
azimut_mask = [270,330]
elevation_mask = [0,250]
min_height = 2
max_height = 10 # meter
time_length = 25 # minutes
time_dict,height_dict,azimut_dict,elevation_dict,frequency_dict,power_dict = esth.estimate_all_satellite(main_path,azimut_mask,elevation_mask,min_height,max_height,time_length)

# %%
for satellite_code in time_dict:
    for i,_ in enumerate(elevation_dict[satellite_code]):
        plt.scatter(elevation_dict[satellite_code][i]['avg'],height_dict[satellite_code][i])

plt.legend(loc="best")
plt.xlabel('elevation')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0.5, 0, 'elevation')

# %%
lib_plot.plot_ele_azi_height('2022-0811#2',azimut_dict=azimut_dict,elevation_dict=elevation_dict,height_dict=height_dict)

# %%
# lib_plot.plot_fresnel_zone(time_str="2022-08-11",equipment_index=2,azimut_dict=azimut_dict,elevation_dict=elevation_dict,height_dict=height_dict)

# %%
main_path = os.path.abspath('../data/20220811/3/')
data_dict = dafi.generate_dataframe(main_path)
satellite_list = data_dict.keys()
azimut_mask = [270,330]
elevation_mask = [0,50]
min_height = 2
max_height = 10 # meter
time_length = 25 # minutes
time_dict,height_dict,azimut_dict,elevation_dict,frequency_dict,power_dict = esth.estimate_all_satellite(main_path,azimut_mask,elevation_mask,min_height,max_height,time_length)

# %%
for satellite_code in time_dict:
    for i,_ in enumerate(elevation_dict[satellite_code]):
        plt.scatter(elevation_dict[satellite_code][i]['avg'],height_dict[satellite_code][i])

plt.legend(loc="best")
plt.xlabel('elevation')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0.5, 0, 'elevation')

# %%
lib_plot.plot_ele_azi_height('2022-08-11#3',azimut_dict=azimut_dict,elevation_dict=elevation_dict,height_dict=height_dict)

# %%
# lib_plot.plot_fresnel_zone(time_str="2022-08-11",equipment_index=3,azimut_dict=azimut_dict,elevation_dict=elevation_dict,height_dict=height_dict)

# %%
main_path = os.path.abspath('../data/20220907/2/')
data_dict = dafi.generate_dataframe(main_path)
satellite_list = data_dict.keys()
azimut_mask = [270,330]
elevation_mask = [0,50]
min_height = 2
max_height = 10 # meter
time_length = 25 # minutes
time_dict,height_dict,azimut_dict,elevation_dict,frequency_dict,power_dict = esth.estimate_all_satellite(main_path,azimut_mask,elevation_mask,min_height,max_height,time_length)

# %%
for satellite_code in time_dict:
    for i,_ in enumerate(elevation_dict[satellite_code]):
        plt.scatter(elevation_dict[satellite_code][i]['avg'],height_dict[satellite_code][i])

plt.legend(loc="best")
plt.xlabel('elevation')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0.5, 0, 'elevation')

# %%
lib_plot.plot_ele_azi_height(azimut_dict=azimut_dict,elevation_dict=elevation_dict,height_dict=height_dict)

# %%
# lib_plot.plot_fresnel_zone(time_str="2022-09-07",equipment_index=2,azimut_dict=azimut_dict,elevation_dict=elevation_dict,height_dict=height_dict)

# %%
main_path = os.path.abspath('../data/20220907/3/')
data_dict = dafi.generate_dataframe(main_path)
satellite_list = data_dict.keys()
azimut_mask = [270,330]
elevation_mask = [0,50]
min_height = 2
max_height = 10 # meter
time_length = 25 # minutes
time_dict,height_dict,azimut_dict,elevation_dict,frequency_dict,power_dict = esth.estimate_all_satellite(main_path,azimut_mask,elevation_mask,min_height,max_height,time_length)

# %%
for satellite_code in time_dict:
    for i,_ in enumerate(elevation_dict[satellite_code]):
        plt.scatter(elevation_dict[satellite_code][i]['avg'],height_dict[satellite_code][i])

plt.legend(loc="best")
plt.xlabel('elevation')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0.5, 0, 'elevation')

# %%
lib_plot.plot_ele_azi_height(azimut_dict=azimut_dict,elevation_dict=elevation_dict,height_dict=height_dict)

# %%
# lib_plot.plot_fresnel_zone(time_str="2022-09-07",equipment_index=3,azimut_dict=azimut_dict,elevation_dict=elevation_dict,height_dict=height_dict)

# %%
main_path = os.path.abspath('../data/20221004/2/')
data_dict = dafi.generate_dataframe(main_path)
satellite_list = data_dict.keys()
azimut_mask = [270,330]
elevation_mask = [0,50]
min_height = 2
max_height = 10 # meter
time_length = 25 # minutes
time_dict,height_dict,azimut_dict,elevation_dict,frequency_dict,power_dict = esth.estimate_all_satellite(main_path,azimut_mask,elevation_mask,min_height,max_height,time_length)

# %%
for satellite_code in time_dict:
    for i,_ in enumerate(elevation_dict[satellite_code]):
        plt.scatter(elevation_dict[satellite_code][i]['avg'],height_dict[satellite_code][i])

plt.legend(loc="best")
plt.xlabel('elevation')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0.5, 0, 'elevation')

# %%
lib_plot.plot_ele_azi_height(azimut_dict=azimut_dict,elevation_dict=elevation_dict,height_dict=height_dict)

# %%
# lib_plot.plot_fresnel_zone(time_str="2022-10-04",equipment_index=2,azimut_dict=azimut_dict,elevation_dict=elevation_dict,height_dict=height_dict)

# %%
main_path = os.path.abspath('../data/20221004/3/')
data_dict = dafi.generate_dataframe(main_path)
satellite_list = data_dict.keys()
azimut_mask = [270,330]
elevation_mask = [0,50]
min_height = 2
max_height = 10 # meter
time_length = 25 # minutes
time_dict,height_dict,azimut_dict,elevation_dict,frequency_dict,power_dict = esth.estimate_all_satellite(main_path,azimut_mask,elevation_mask,min_height,max_height,time_length)

# %%
for satellite_code in time_dict:
    for i,_ in enumerate(elevation_dict[satellite_code]):
        plt.scatter(elevation_dict[satellite_code][i]['avg'],height_dict[satellite_code][i])

plt.legend(loc="best")
plt.xlabel('elevation')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0.5, 0, 'elevation')

# %%
lib_plot.plot_ele_azi_height(azimut_dict=azimut_dict,elevation_dict=elevation_dict,height_dict=height_dict)

# %%
# lib_plot.plot_fresnel_zone(time_str="2022-10-04",equipment_index=3,azimut_dict=azimut_dict,elevation_dict=elevation_dict,height_dict=height_dict)

# %%
main_path = os.path.abspath('../data/20221031/2/')
data_dict = dafi.generate_dataframe(main_path)
satellite_list = data_dict.keys()
azimut_mask = [270,330]
elevation_mask = [0,50]
min_height = 2
max_height = 10 # meter
time_length = 25 # minutes
time_dict,height_dict,azimut_dict,elevation_dict,frequency_dict,power_dict = esth.estimate_all_satellite(main_path,azimut_mask,elevation_mask,min_height,max_height,time_length)

# %%
for satellite_code in time_dict:
    for i,_ in enumerate(elevation_dict[satellite_code]):
        plt.scatter(elevation_dict[satellite_code][i]['avg'],height_dict[satellite_code][i])

plt.legend(loc="best")
plt.xlabel('elevation')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0.5, 0, 'elevation')

# %%
lib_plot.plot_ele_azi_height(azimut_dict=azimut_dict,elevation_dict=elevation_dict,height_dict=height_dict)

# %%
# lib_plot.plot_fresnel_zone(time_str="2022-10-31",equipment_index=2,azimut_dict=azimut_dict,elevation_dict=elevation_dict,height_dict=height_dict)

# %%
main_path = os.path.abspath('../data/20221031/3/')
data_dict = dafi.generate_dataframe(main_path)
satellite_list = data_dict.keys()
azimut_mask = [270,330]
elevation_mask = [0,50]
min_height = 2
max_height = 10 # meter
time_length = 25 # minutes
time_dict,height_dict,azimut_dict,elevation_dict,frequency_dict,power_dict = esth.estimate_all_satellite(main_path,azimut_mask,elevation_mask,min_height,max_height,time_length)

# %%
for satellite_code in time_dict:
    for i,_ in enumerate(elevation_dict[satellite_code]):
        plt.scatter(elevation_dict[satellite_code][i]['avg'],height_dict[satellite_code][i])

plt.legend(loc="best")
plt.xlabel('elevation')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0.5, 0, 'elevation')

# %%
lib_plot.plot_ele_azi_height(azimut_dict=azimut_dict,elevation_dict=elevation_dict,height_dict=height_dict)

# %%
# lib_plot.plot_fresnel_zone(time_str="2022-10-31",equipment_index=3,azimut_dict=azimut_dict,elevation_dict=elevation_dict,height_dict=height_dict)

# %%
main_path = os.path.abspath('../data/20221104/2/')
data_dict = dafi.generate_dataframe(main_path)
satellite_list = data_dict.keys()
azimut_mask = [300,330]
elevation_mask = [0,50]
min_height = 8
max_height = 16 # meter
time_length = 25 # minutes
time_dict,height_dict,azimut_dict,elevation_dict,frequency_dict,power_dict = esth.estimate_all_satellite(main_path,azimut_mask,elevation_mask,min_height,max_height,time_length)

# %%
for satellite_code in time_dict:
    for i,_ in enumerate(elevation_dict[satellite_code]):
        plt.scatter(elevation_dict[satellite_code][i]['avg'],height_dict[satellite_code][i])

plt.legend(loc="best")
plt.xlabel('elevation')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0.5, 0, 'elevation')

# %%
# lib_plot.plot_fresnel_zone(time_str="2022-11-04",equipment_index=2,azimut_dict=azimut_dict,elevation_dict=elevation_dict,height_dict=height_dict)

# %%
main_path = os.path.abspath('../data/20221104/3/')
data_dict = dafi.generate_dataframe(main_path)
satellite_list = data_dict.keys()
azimut_mask = [155,180]
elevation_mask = [0,50]
min_height = 8
max_height = 16 # meter
time_length = 25 # minutes
time_dict,height_dict,azimut_dict,elevation_dict,frequency_dict,power_dict = esth.estimate_all_satellite(main_path,azimut_mask,elevation_mask,min_height,max_height,time_length)

# %%
for satellite_code in time_dict:
    for i,_ in enumerate(elevation_dict[satellite_code]):
        plt.scatter(elevation_dict[satellite_code][i]['avg'],height_dict[satellite_code][i])

plt.legend(loc="best")
plt.xlabel('elevation')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0.5, 0, 'elevation')

# %%
# lib_plot.plot_fresnel_zone(time_str="2022-11-04",equipment_index=3,azimut_dict=azimut_dict,elevation_dict=elevation_dict,height_dict=height_dict)
