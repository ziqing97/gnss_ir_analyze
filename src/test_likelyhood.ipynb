# %%
import os
from datetime import timedelta
from csv import reader

import numpy as np
import pandas as pd
from astropy.timeseries import LombScargle

import matplotlib.pyplot as plt

from scipy import signal

import data_filter as dafi
import estimate_height as esth
import lib_plot

apikey="AIzaSyBe1VW572pITHH7OBLt1Ziy1e9y0dl4kWw"

color_dict = lib_plot.get_satellite_color()

# %%
C = 299792458 # m/s
FREQUENCY_GPS_L1 = 1575.42 * 10**6
WAVELENTH_GPS_S1 = C/FREQUENCY_GPS_L1

FREQUENCY_GLONASS_L1 = 1602 * 10**6
WAVELENTH_GLONASS_S1 = C/FREQUENCY_GLONASS_L1

# %%
meas_file = os.path.abspath("../data/documentation.xlsx")
df_meas = pd.read_excel(meas_file)

# %%
main_path = os.path.abspath('../data/20220811/2/')
data_dict = dafi.generate_dataframe(main_path)
satellite_list = data_dict.keys()
azimut_mask = [270,330]
elevation_mask = [0,60]
min_height = 2
max_height = 10 # meter
time_length = 25 # minutes
time_dict,height_dict,azimut_dict,elevation_dict,frequency_dict,power_dict = esth.estimate_all_satellite(main_path,azimut_mask,elevation_mask,min_height,max_height,time_length)

# %%
frequency,power_likelyhood = esth.generate_likelyhood(frequency_dict,power_dict)
plt.plot(frequency,power_likelyhood)
peaks = (power_likelyhood == power_likelyhood.max())
frequency[peaks]
# Out:
# array([2.928])

# %%
main_path = os.path.abspath('../data/20220811/3/')
data_dict = dafi.generate_dataframe(main_path)
satellite_list = data_dict.keys()
azimut_mask = [270,330]
elevation_mask = [0,60]
min_height = 2
max_height = 10 # meter
time_length = 25 # minutes
time_dict,height_dict,azimut_dict,elevation_dict,frequency_dict,power_dict = esth.estimate_all_satellite(main_path,azimut_mask,elevation_mask,min_height,max_height,time_length)

# %%
frequency,power_likelyhood = esth.generate_likelyhood(frequency_dict,power_dict)
plt.plot(frequency,power_likelyhood)
peaks = (power_likelyhood == power_likelyhood.max())
frequency[peaks]
# Out:
# array([3.107])

# %%
main_path = os.path.abspath('../data/20220907/2/')
data_dict = dafi.generate_dataframe(main_path)
satellite_list = data_dict.keys()
azimut_mask = [270,330]
elevation_mask = [0,60]
min_height = 2
max_height = 10 # meter
time_length = 25 # minutes
time_dict,height_dict,azimut_dict,elevation_dict,frequency_dict,power_dict = esth.estimate_all_satellite(main_path,azimut_mask,elevation_mask,min_height,max_height,time_length)

# %%
frequency,power_likelyhood = esth.generate_likelyhood(frequency_dict,power_dict)
plt.plot(frequency,power_likelyhood)
peaks = (power_likelyhood == power_likelyhood.max())
frequency[peaks]
# Out:
# array([3.015])

# %%
main_path = os.path.abspath('../data/20220907/3/')
data_dict = dafi.generate_dataframe(main_path)
satellite_list = data_dict.keys()
azimut_mask = [270,330]
elevation_mask = [0,60]
min_height = 2
max_height = 10 # meter
time_length = 25 # minutes
time_dict,height_dict,azimut_dict,elevation_dict,frequency_dict,power_dict = esth.estimate_all_satellite(main_path,azimut_mask,elevation_mask,min_height,max_height,time_length)

# %%
frequency,power_likelyhood = esth.generate_likelyhood(frequency_dict,power_dict)
plt.plot(frequency,power_likelyhood)
peaks = (power_likelyhood == power_likelyhood.max())
frequency[peaks]
# Out:
# array([3.158])

# %%
main_path = os.path.abspath('../data/20221004/2/')
data_dict = dafi.generate_dataframe(main_path)
satellite_list = data_dict.keys()
azimut_mask = [270,330]
elevation_mask = [0,60]
min_height = 2
max_height = 10 # meter
time_length = 25 # minutes
time_dict,height_dict,azimut_dict,elevation_dict,frequency_dict,power_dict = esth.estimate_all_satellite(main_path,azimut_mask,elevation_mask,min_height,max_height,time_length)

# %%
frequency,power_likelyhood = esth.generate_likelyhood(frequency_dict,power_dict)
plt.plot(frequency,power_likelyhood)
peaks = (power_likelyhood == power_likelyhood.max())
frequency[peaks]
# Out:
# array([3.169])

# %%
main_path = os.path.abspath('../data/20221004/3/')
data_dict = dafi.generate_dataframe(main_path)
satellite_list = data_dict.keys()
azimut_mask = [270,330]
elevation_mask = [0,60]
min_height = 2
max_height = 10 # meter
time_length = 25 # minutes
time_dict,height_dict,azimut_dict,elevation_dict,frequency_dict,power_dict = esth.estimate_all_satellite(main_path,azimut_mask,elevation_mask,min_height,max_height,time_length)

# %%
frequency,power_likelyhood = esth.generate_likelyhood(frequency_dict,power_dict)
plt.plot(frequency,power_likelyhood)
peaks = (power_likelyhood == power_likelyhood.max())
frequency[peaks]
# Out:
# array([3.029])

# %%
main_path = os.path.abspath('../data/20221031/2/')
data_dict = dafi.generate_dataframe(main_path)
satellite_list = data_dict.keys()
azimut_mask = [270,330]
elevation_mask = [0,60]
min_height = 2
max_height = 6 # meter
time_length = 25 # minutes
time_dict,height_dict,azimut_dict,elevation_dict,frequency_dict,power_dict = esth.estimate_all_satellite(main_path,azimut_mask,elevation_mask,min_height,max_height,time_length)

# %%
frequency,power_likelyhood = esth.generate_likelyhood(frequency_dict,power_dict)
plt.plot(frequency,power_likelyhood)
peaks = (power_likelyhood == power_likelyhood.max())
frequency[peaks]
# Out:
# array([3.126])

# %%
main_path = os.path.abspath('../data/20221031/3/')
data_dict = dafi.generate_dataframe(main_path)
satellite_list = data_dict.keys()
azimut_mask = [270,330]
elevation_mask = [0,60]
min_height = 2
max_height = 5 # meter
time_length = 20 # minutes
time_dict,height_dict,azimut_dict,elevation_dict,frequency_dict,power_dict = esth.estimate_all_satellite(main_path,azimut_mask,elevation_mask,min_height,max_height,time_length)

# %%
frequency,power_likelyhood = esth.generate_likelyhood(frequency_dict,power_dict)
peaks = (power_likelyhood == power_likelyhood.max())
frequency[peaks]
# Out:
# array([3.11])

# %%
area = np.sum(np.multiply((frequency[2:]-frequency[0:-2])/2, power_likelyhood[1:-1]))
scale = 1/area
power_likelyhood_scaled = power_likelyhood*scale

# %%
power_norm_dict = {}
for satellite_code in power_dict:
    power_norm_dict[satellite_code] = []
    for item in power_dict[satellite_code]:
        area = np.sum(np.multiply((frequency[2:]-frequency[0:-2])/2, item[1:-1]))
        scale = 1/area
        power_norm_dict[satellite_code].append(item*scale)
        plt.plot(frequency,scale*item)
plt.plot(frequency,power_likelyhood_scaled)

# %%
def calculate_overlap(x,y1,y2):
    low_index_1 = y1 > y2
    low_index_2 = ~low_index_1

    plt.plot(x[low_index_2],y1[low_index_2])
    plt.plot(x[low_index_1],y2[low_index_1])

    area1 = sum(np.multiply((x[low_index_2][2:] - x[low_index_2][0:-2])/2, y1[low_index_2][1:-1]))
    area2 = sum(np.multiply((x[low_index_1][2:] - x[low_index_1][0:-2])/2, y2[low_index_1][1:-1]))

    return area1+area2

# %%
overlap_dict = {}
height_dict_new = height_dict.copy()
for satellite_code in power_norm_dict:
    overlap_dict[satellite_code] = []
    for i,item in enumerate(power_norm_dict[satellite_code]):
        overlap_area = calculate_overlap(frequency,item,power_likelyhood_scaled)
        overlap_dict[satellite_code].append(overlap_area)
        if overlap_area<0.2:
            height_dict_new[satellite_code][i] = None

# %%
for satellite_code in time_dict:
    for i,item in enumerate(elevation_dict[satellite_code]):
        plt.scatter(item['avg'],overlap_dict[satellite_code][i])
