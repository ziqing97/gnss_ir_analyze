# %%
import os
import transformation
import math
import pandas as pd
import numpy as np

import gmplot

# %%
coor_file = os.path.abspath("../data/documentation.xlsx")
df_coor = pd.read_excel(coor_file)
df_coor
# Out:
#          time        location  equipment  latitude  longitude  height(GNSS)
# 0  2022-05-22  Ober Esslingen          2  48.72768    9.32381     285.73854
# 1  2022-05-22  Ober Esslingen          3  48.72821    9.32403     286.30214
# 2  2022-05-26   Bad-Cannstatt          2  48.79764    9.21425     270.97025
# 3  2022-05-26   Bad-Cannstatt          3  48.79782    9.21400     282.72263
# 4  2022-06-18  Ober Esslingen          2  48.72820    9.32409     291.89773
# 5  2022-06-18  Ober Esslingen          3  48.72771    9.32391     293.26101
# 6  2022-06-22   Bad-Cannstatt          2  48.79810    9.21388     275.49862
# 7  2022-06-22   Bad-Cannstatt          3  48.79696    9.21382     273.06919
# 8  2022-07-15  Ober Esslingen          2  48.72823    9.32409     286.67937
# 9  2022-07-15  Ober Esslingen          3  48.72770    9.32399     292.62920
# 10 2022-08-11  Ober Esslingen          2  48.72860    9.31907     285.48789
# ...

# %%
apikey="AIzaSyBe1VW572pITHH7OBLt1Ziy1e9y0dl4kWw"
lat = df_coor.iloc[0]['latitude']
lon = df_coor.iloc[0]['longitude']

gmap_esslingen = gmplot.GoogleMapPlotter(lat,lon, 15)
gmap_esslingen.scatter([lat], [lon], '#FF0000', size = 1, marker = True)

# %%
elevation = 15
height = 3

distance = height / np.tan(elevation/180*np.pi)
azimut = 0
north = distance * np.cos(azimut/180*np.pi)
east = distance * np.cos(azimut/180*np.pi)

# %%
gmap_esslingen.draw("test.html")
